# %% [markdown]
# Ejemplo sobre IRIS que son datos de un tipo de flor

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("data/iris.data")
df
# Out:
#      5.1  3.5  1.4  0.2     Iris-setosa
# 0    4.9  3.0  1.4  0.2     Iris-setosa
# 1    4.7  3.2  1.3  0.2     Iris-setosa
# 2    4.6  3.1  1.5  0.2     Iris-setosa
# 3    5.0  3.6  1.4  0.2     Iris-setosa
# 4    5.4  3.9  1.7  0.4     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 144  6.7  3.0  5.2  2.3  Iris-virginica
# 145  6.3  2.5  5.0  1.9  Iris-virginica
# 146  6.5  3.0  5.2  2.0  Iris-virginica
# 147  6.2  3.4  5.4  2.3  Iris-virginica
# 148  5.9  3.0  5.1  1.8  Iris-virginica
#
# [149 rows x 5 columns]

# %% [markdown]
# Dibujamos las últimas filas

# %%
df.tail()
# Out:
#      5.1  3.5  1.4  0.2     Iris-setosa
# 144  6.7  3.0  5.2  2.3  Iris-virginica
# 145  6.3  2.5  5.0  1.9  Iris-virginica
# 146  6.5  3.0  5.2  2.0  Iris-virginica
# 147  6.2  3.4  5.4  2.3  Iris-virginica
# 148  5.9  3.0  5.1  1.8  Iris-virginica

# %% [markdown]
# Podemos establecer columnas para nuestro DataFrame

# %%
df.columns = ["longitud_sepalo", "ancho_sepalo", "longitud_petalo", "ancho_petalo", "clase"]
df
# Out:
#      longitud_sepalo  ancho_sepalo  longitud_petalo  ancho_petalo  \
# 0                4.9           3.0              1.4           0.2
# 1                4.7           3.2              1.3           0.2
# 2                4.6           3.1              1.5           0.2
# 3                5.0           3.6              1.4           0.2
# 4                5.4           3.9              1.7           0.4
# ..               ...           ...              ...           ...
# 144              6.7           3.0              5.2           2.3
# 145              6.3           2.5              5.0           1.9
# 146              6.5           3.0              5.2           2.0
# 147              6.2           3.4              5.4           2.3
# 148              5.9           3.0              5.1           1.8
#
#               clase
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 144  Iris-virginica
# ...

# %%
df.describe()
# Out:
#        longitud_sepalo  ancho_sepalo  logitud_petalo  ancho_petalo
# count       149.000000    149.000000      149.000000    149.000000
# mean          5.848322      3.051007        3.774497      1.205369
# std           0.828594      0.433499        1.759651      0.761292
# min           4.300000      2.000000        1.000000      0.100000
# 25%           5.100000      2.800000        1.600000      0.300000
# 50%           5.800000      3.000000        4.400000      1.300000
# 75%           6.400000      3.300000        5.100000      1.800000
# max           7.900000      4.400000        6.900000      2.500000

# %% [markdown]
# Podemos contar valores por una columna

# %%
df['clase'].value_counts()
# Out:
# clase
# Iris-versicolor    50
# Iris-virginica     50
# Iris-setosa        49
# Name: count, dtype: int64

# %% [markdown]
# Ordenar datos ascendente y descendente

# %%
#df.sort_values('ancho_sepalo')
df.sort_values('ancho_sepalo', ascending=False)
# Out:
#      longitud_sepalo  ancho_sepalo  logitud_petalo  ancho_petalo  \
# 14               5.7           4.4             1.5           0.4
# 32               5.5           4.2             1.4           0.2
# 31               5.2           4.1             1.5           0.1
# 13               5.8           4.0             1.2           0.2
# 4                5.4           3.9             1.7           0.4
# ..               ...           ...             ...           ...
# 52               5.5           2.3             4.0           1.3
# 67               6.2           2.2             4.5           1.5
# 61               6.0           2.2             4.0           1.0
# 118              6.0           2.2             5.0           1.5
# 59               5.0           2.0             3.5           1.0
#
#                clase
# 14       Iris-setosa
# 32       Iris-setosa
# 31       Iris-setosa
# 13       Iris-setosa
# 4        Iris-setosa
# ..               ...
# 52   Iris-versicolor
# ...

# %% [markdown]
# Podemos cambiar filas por columnas

# %%
df.T
# Out:
#                          0            1            2            3    \
# longitud_sepalo          4.9          4.7          4.6          5.0
# ancho_sepalo             3.0          3.2          3.1          3.6
# logitud_petalo           1.4          1.3          1.5          1.4
# ancho_petalo             0.2          0.2          0.2          0.2
# clase            Iris-setosa  Iris-setosa  Iris-setosa  Iris-setosa
#
#                          4            5            6            7    \
# longitud_sepalo          5.4          4.6          5.0          4.4
# ancho_sepalo             3.9          3.4          3.4          2.9
# logitud_petalo           1.7          1.4          1.5          1.4
# ancho_petalo             0.4          0.3          0.2          0.2
# clase            Iris-setosa  Iris-setosa  Iris-setosa  Iris-setosa
#
#                          8            9    ...             139  \
# longitud_sepalo          4.9          5.4  ...             6.7
# ...

# %% [markdown]
# Filtrar por una columna

# %%
df[ df['longitud_petalo'] > 5 ]
# Out:
#      longitud_sepalo  ancho_sepalo  longitud_petalo  ancho_petalo  \
# 82               6.0           2.7              5.1           1.6
# 99               6.3           3.3              6.0           2.5
# 100              5.8           2.7              5.1           1.9
# 101              7.1           3.0              5.9           2.1
# 102              6.3           2.9              5.6           1.8
# 103              6.5           3.0              5.8           2.2
# 104              7.6           3.0              6.6           2.1
# 106              7.3           2.9              6.3           1.8
# 107              6.7           2.5              5.8           1.8
# 108              7.2           3.6              6.1           2.5
# 109              6.5           3.2              5.1           2.0
# 110              6.4           2.7              5.3           1.9
# 111              6.8           3.0              5.5           2.1
# ...

# %% [markdown]
# Filtrar por más de una condición:
# Se utiliza & para AND
# Se utiliza | para OR

# %%
df[ (df['longitud_petalo'] > 5) & (df['ancho_petalo'] < 1.5) ]
# Out:
#      longitud_sepalo  ancho_sepalo  longitud_petalo  ancho_petalo  \
# 133              6.1           2.6              5.6           1.4
#
#               clase
# 133  Iris-virginica

# %% [markdown]
# Comprobar valores perdidos dentro del DataFrame

# %%
df.isna().sum()
# Out:
# longitud_sepalo    0
# ancho_sepalo       0
# longitud_petalo    0
# ancho_petalo       0
# clase              0
# dtype: int64

# %% [markdown]
# Vamos a poner valores nan a alguna columna/fila

# %%
df['longitud_petalo'][:2] = np.nan
df.head()
# Out:
# /var/folders/96/12m1k06d789_shzgr7j_qqy00000gq/T/ipykernel_29598/3228141882.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['longitud_petalo'][:2] = np.nan
# ...

# %% [markdown]
# Mostrar los valores nulos

# %%
df.isna().sum()
# Out:
# longitud_sepalo    0
# ancho_sepalo       0
# longitud_petalo    2
# ancho_petalo       0
# clase              0
# dtype: int64

# %% [markdown]
# Podemos quitar los valores nulos SI sabemos dónde están (fillna)

# %%
df['longitud_petalo'] = df['longitud_petalo'].fillna(2.9)
df.head()
# Out:
#    longitud_sepalo  ancho_sepalo  longitud_petalo  ancho_petalo        clase
# 0              4.9           3.0              2.9           0.2  Iris-setosa
# 1              4.7           3.2              2.9           0.2  Iris-setosa
# 2              4.6           3.1              1.5           0.2  Iris-setosa
# 3              5.0           3.6              1.4           0.2  Iris-setosa
# 4              5.4           3.9              1.7           0.4  Iris-setosa
